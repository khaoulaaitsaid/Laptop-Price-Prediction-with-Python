# %%
import pandas as pd
df = pd.read_csv("laptop_price.csv", encoding="latin-1")
df
# Out:
#       laptop_ID Company                              Product  \
# 0             1   Apple                          MacBook Pro
# 1             2   Apple                          Macbook Air
# 2             3      HP                               250 G6
# 3             4   Apple                          MacBook Pro
# 4             5   Apple                          MacBook Pro
# ...         ...     ...                                  ...
# 1298       1316  Lenovo                       Yoga 500-14ISK
# 1299       1317  Lenovo                       Yoga 900-13ISK
# 1300       1318  Lenovo                   IdeaPad 100S-14IBR
# 1301       1319      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1302       1320    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)
#
#                 TypeName  Inches                            ScreenResolution  \
# 0              Ultrabook    13.3          IPS Panel Retina Display 2560x1600
# 1              Ultrabook    13.3                                    1440x900
# 2               Notebook    15.6                           Full HD 1920x1080
# 3              Ultrabook    15.4          IPS Panel Retina Display 2880x1800
# 4              Ultrabook    13.3          IPS Panel Retina Display 2560x1600
# ...                  ...     ...                                         ...
# 1298  2 in 1 Convertible    14.0   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  2 in 1 Convertible    13.3  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1300            Notebook    14.0                                    1366x768
# 1301            Notebook    15.6                                    1366x768
# 1302            Notebook    15.6                                    1366x768
#
#                                        Cpu   Ram               Memory  \
# 0                     Intel Core i5 2.3GHz   8GB            128GB SSD
# 1                     Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2               Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3                     Intel Core i7 2.7GHz  16GB            512GB SSD
# 4                     Intel Core i5 3.1GHz   8GB            256GB SSD
# ...                                    ...   ...                  ...
# 1298            Intel Core i7 6500U 2.5GHz   4GB            128GB SSD
# 1299            Intel Core i7 6500U 2.5GHz  16GB            512GB SSD
# 1300  Intel Celeron Dual Core N3050 1.6GHz   2GB   64GB Flash Storage
# 1301            Intel Core i7 6500U 2.5GHz   6GB              1TB HDD
# 1302  Intel Celeron Dual Core N3050 1.6GHz   4GB            500GB HDD
#
#                                Gpu       OpSys  Weight  Price_euros
# 0     Intel Iris Plus Graphics 640       macOS  1.37kg      1339.69
# 1           Intel HD Graphics 6000       macOS  1.34kg       898.94
# 2            Intel HD Graphics 620       No OS  1.86kg       575.00
# 3               AMD Radeon Pro 455       macOS  1.83kg      2537.45
# 4     Intel Iris Plus Graphics 650       macOS  1.37kg      1803.60
# ...                            ...         ...     ...          ...
# 1298         Intel HD Graphics 520  Windows 10   1.8kg       638.00
# 1299         Intel HD Graphics 520  Windows 10   1.3kg      1499.00
# 1300             Intel HD Graphics  Windows 10   1.5kg       229.00
# 1301            AMD Radeon R5 M330  Windows 10  2.19kg       764.00
# 1302             Intel HD Graphics  Windows 10   2.2kg       369.00
#
# [1303 rows x 13 columns]

# %%
df.Product.value_counts()
# Out:
# Product
# XPS 13                                     30
# Inspiron 3567                              29
# 250 G6                                     21
# Legion Y520-15IKBN                         19
# Vostro 3568                                19
#                                            ..
# 15-bw007nv (A10-9620P/6GB/128GB/Radeon      1
# SmartBook 130                               1
# A541NA-GO342 (N3350/4GB/500GB/Linux)        1
# 17-X047na (i3-6006U/8GB/1TB/W10)            1
# V330-15IKB (i5-8250U/4GB/500GB/FHD/W10)     1
# Name: count, Length: 618, dtype: int64

# %%
df = df.drop("Product", axis=1)
df
# Out:
#       laptop_ID Company            TypeName  Inches  \
# 0             1   Apple           Ultrabook    13.3
# 1             2   Apple           Ultrabook    13.3
# 2             3      HP            Notebook    15.6
# 3             4   Apple           Ultrabook    15.4
# 4             5   Apple           Ultrabook    13.3
# ...         ...     ...                 ...     ...
# 1298       1316  Lenovo  2 in 1 Convertible    14.0
# 1299       1317  Lenovo  2 in 1 Convertible    13.3
# 1300       1318  Lenovo            Notebook    14.0
# 1301       1319      HP            Notebook    15.6
# 1302       1320    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1300                                    1366x768
# 1301                                    1366x768
# 1302                                    1366x768
#
#                                        Cpu   Ram               Memory  \
# 0                     Intel Core i5 2.3GHz   8GB            128GB SSD
# 1                     Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2               Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3                     Intel Core i7 2.7GHz  16GB            512GB SSD
# 4                     Intel Core i5 3.1GHz   8GB            256GB SSD
# ...                                    ...   ...                  ...
# 1298            Intel Core i7 6500U 2.5GHz   4GB            128GB SSD
# 1299            Intel Core i7 6500U 2.5GHz  16GB            512GB SSD
# 1300  Intel Celeron Dual Core N3050 1.6GHz   2GB   64GB Flash Storage
# 1301            Intel Core i7 6500U 2.5GHz   6GB              1TB HDD
# 1302  Intel Celeron Dual Core N3050 1.6GHz   4GB            500GB HDD
#
#                                Gpu       OpSys  Weight  Price_euros
# 0     Intel Iris Plus Graphics 640       macOS  1.37kg      1339.69
# 1           Intel HD Graphics 6000       macOS  1.34kg       898.94
# 2            Intel HD Graphics 620       No OS  1.86kg       575.00
# 3               AMD Radeon Pro 455       macOS  1.83kg      2537.45
# 4     Intel Iris Plus Graphics 650       macOS  1.37kg      1803.60
# ...                            ...         ...     ...          ...
# 1298         Intel HD Graphics 520  Windows 10   1.8kg       638.00
# 1299         Intel HD Graphics 520  Windows 10   1.3kg      1499.00
# 1300             Intel HD Graphics  Windows 10   1.5kg       229.00
# 1301            AMD Radeon R5 M330  Windows 10  2.19kg       764.00
# 1302             Intel HD Graphics  Windows 10   2.2kg       369.00
#
# [1303 rows x 12 columns]

# %%
df = df.join(pd.get_dummies(df.Company))
df = df.drop('Company', axis=1)
df
# Out:
#       laptop_ID            TypeName  Inches  \
# 0             1           Ultrabook    13.3
# 1             2           Ultrabook    13.3
# 2             3            Notebook    15.6
# 3             4           Ultrabook    15.4
# 4             5           Ultrabook    13.3
# ...         ...                 ...     ...
# 1298       1316  2 in 1 Convertible    14.0
# 1299       1317  2 in 1 Convertible    13.3
# 1300       1318            Notebook    14.0
# 1301       1319            Notebook    15.6
# 1302       1320            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1300                                    1366x768
# 1301                                    1366x768
# 1302                                    1366x768
#
#                                        Cpu   Ram               Memory  \
# 0                     Intel Core i5 2.3GHz   8GB            128GB SSD
# 1                     Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2               Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3                     Intel Core i7 2.7GHz  16GB            512GB SSD
# 4                     Intel Core i5 3.1GHz   8GB            256GB SSD
# ...                                    ...   ...                  ...
# 1298            Intel Core i7 6500U 2.5GHz   4GB            128GB SSD
# 1299            Intel Core i7 6500U 2.5GHz  16GB            512GB SSD
# 1300  Intel Celeron Dual Core N3050 1.6GHz   2GB   64GB Flash Storage
# 1301            Intel Core i7 6500U 2.5GHz   6GB              1TB HDD
# 1302  Intel Celeron Dual Core N3050 1.6GHz   4GB            500GB HDD
#
#                                Gpu       OpSys  Weight  ...     LG  Lenovo  \
# 0     Intel Iris Plus Graphics 640       macOS  1.37kg  ...  False   False
# 1           Intel HD Graphics 6000       macOS  1.34kg  ...  False   False
# 2            Intel HD Graphics 620       No OS  1.86kg  ...  False   False
# 3               AMD Radeon Pro 455       macOS  1.83kg  ...  False   False
# 4     Intel Iris Plus Graphics 650       macOS  1.37kg  ...  False   False
# ...                            ...         ...     ...  ...    ...     ...
# 1298         Intel HD Graphics 520  Windows 10   1.8kg  ...  False    True
# 1299         Intel HD Graphics 520  Windows 10   1.3kg  ...  False    True
# 1300             Intel HD Graphics  Windows 10   1.5kg  ...  False    True
# 1301            AMD Radeon R5 M330  Windows 10  2.19kg  ...  False   False
# 1302             Intel HD Graphics  Windows 10   2.2kg  ...  False   False
#
#         MSI  Mediacom  Microsoft  Razer  Samsung  Toshiba   Vero  Xiaomi
# 0     False     False      False  False    False    False  False   False
# 1     False     False      False  False    False    False  False   False
# 2     False     False      False  False    False    False  False   False
# 3     False     False      False  False    False    False  False   False
# 4     False     False      False  False    False    False  False   False
# ...     ...       ...        ...    ...      ...      ...    ...     ...
# 1298  False     False      False  False    False    False  False   False
# 1299  False     False      False  False    False    False  False   False
# 1300  False     False      False  False    False    False  False   False
# 1301  False     False      False  False    False    False  False   False
# 1302  False     False      False  False    False    False  False   False
#
# [1303 rows x 30 columns]

# %%
df = df.join(pd.get_dummies(df.TypeName))
df = df.drop('TypeName', axis=1)
df
# Out:
#       laptop_ID  Inches                            ScreenResolution  \
# 0             1    13.3          IPS Panel Retina Display 2560x1600
# 1             2    13.3                                    1440x900
# 2             3    15.6                           Full HD 1920x1080
# 3             4    15.4          IPS Panel Retina Display 2880x1800
# 4             5    13.3          IPS Panel Retina Display 2560x1600
# ...         ...     ...                                         ...
# 1298       1316    14.0   IPS Panel Full HD / Touchscreen 1920x1080
# 1299       1317    13.3  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1300       1318    14.0                                    1366x768
# 1301       1319    15.6                                    1366x768
# 1302       1320    15.6                                    1366x768
#
#                                        Cpu   Ram               Memory  \
# 0                     Intel Core i5 2.3GHz   8GB            128GB SSD
# 1                     Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2               Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3                     Intel Core i7 2.7GHz  16GB            512GB SSD
# 4                     Intel Core i5 3.1GHz   8GB            256GB SSD
# ...                                    ...   ...                  ...
# 1298            Intel Core i7 6500U 2.5GHz   4GB            128GB SSD
# 1299            Intel Core i7 6500U 2.5GHz  16GB            512GB SSD
# 1300  Intel Celeron Dual Core N3050 1.6GHz   2GB   64GB Flash Storage
# 1301            Intel Core i7 6500U 2.5GHz   6GB              1TB HDD
# 1302  Intel Celeron Dual Core N3050 1.6GHz   4GB            500GB HDD
#
#                                Gpu       OpSys  Weight  Price_euros  ...  \
# 0     Intel Iris Plus Graphics 640       macOS  1.37kg      1339.69  ...
# 1           Intel HD Graphics 6000       macOS  1.34kg       898.94  ...
# 2            Intel HD Graphics 620       No OS  1.86kg       575.00  ...
# 3               AMD Radeon Pro 455       macOS  1.83kg      2537.45  ...
# 4     Intel Iris Plus Graphics 650       macOS  1.37kg      1803.60  ...
# ...                            ...         ...     ...          ...  ...
# 1298         Intel HD Graphics 520  Windows 10   1.8kg       638.00  ...
# 1299         Intel HD Graphics 520  Windows 10   1.3kg      1499.00  ...
# 1300             Intel HD Graphics  Windows 10   1.5kg       229.00  ...
# 1301            AMD Radeon R5 M330  Windows 10  2.19kg       764.00  ...
# 1302             Intel HD Graphics  Windows 10   2.2kg       369.00  ...
#
#       Samsung  Toshiba   Vero  Xiaomi  2 in 1 Convertible  Gaming  Netbook  \
# 0       False    False  False   False               False   False    False
# 1       False    False  False   False               False   False    False
# 2       False    False  False   False               False   False    False
# 3       False    False  False   False               False   False    False
# 4       False    False  False   False               False   False    False
# ...       ...      ...    ...     ...                 ...     ...      ...
# 1298    False    False  False   False                True   False    False
# 1299    False    False  False   False                True   False    False
# 1300    False    False  False   False               False   False    False
# 1301    False    False  False   False               False   False    False
# 1302    False    False  False   False               False   False    False
#
#       Notebook  Ultrabook  Workstation
# 0        False       True        False
# 1        False       True        False
# 2         True      False        False
# 3        False       True        False
# 4        False       True        False
# ...        ...        ...          ...
# 1298     False      False        False
# 1299     False      False        False
# 1300      True      False        False
# 1301      True      False        False
# 1302      True      False        False
#
# [1303 rows x 35 columns]

# %%
df.ScreenResolution.str.split(" ")
# Out:
# 0                [IPS, Panel, Retina, Display, 2560x1600]
# 1                                              [1440x900]
# 2                                   [Full, HD, 1920x1080]
# 3                [IPS, Panel, Retina, Display, 2880x1800]
# 4                [IPS, Panel, Retina, Display, 2560x1600]
#                               ...
# 1298    [IPS, Panel, Full, HD, /, Touchscreen, 1920x1080]
# 1299    [IPS, Panel, Quad, HD+, /, Touchscreen, 3200x1...
# 1300                                           [1366x768]
# 1301                                           [1366x768]
# 1302                                           [1366x768]
# Name: ScreenResolution, Length: 1303, dtype: object

# %%
df.ScreenResolution.str.split(" ").apply(lambda x: x[-1])
# Out:
# 0       2560x1600
# 1        1440x900
# 2       1920x1080
# 3       2880x1800
# 4       2560x1600
#           ...
# 1298    1920x1080
# 1299    3200x1800
# 1300     1366x768
# 1301     1366x768
# 1302     1366x768
# Name: ScreenResolution, Length: 1303, dtype: object

# %%
df['ScreenResolution'] = df.ScreenResolution.str.split(" ").apply(lambda x: x[-1])
df['Screen width'] = df.ScreenResolution.str.split("x").apply(lambda x: x[0])
df['Screen height'] = df.ScreenResolution.str.split("x").apply(lambda x: x[1])
df = df.drop('ScreenResolution', axis=1)
df
# Out:
#       laptop_ID  Inches                                   Cpu   Ram  \
# 0             1    13.3                  Intel Core i5 2.3GHz   8GB
# 1             2    13.3                  Intel Core i5 1.8GHz   8GB
# 2             3    15.6            Intel Core i5 7200U 2.5GHz   8GB
# 3             4    15.4                  Intel Core i7 2.7GHz  16GB
# 4             5    13.3                  Intel Core i5 3.1GHz   8GB
# ...         ...     ...                                   ...   ...
# 1298       1316    14.0            Intel Core i7 6500U 2.5GHz   4GB
# 1299       1317    13.3            Intel Core i7 6500U 2.5GHz  16GB
# 1300       1318    14.0  Intel Celeron Dual Core N3050 1.6GHz   2GB
# 1301       1319    15.6            Intel Core i7 6500U 2.5GHz   6GB
# 1302       1320    15.6  Intel Celeron Dual Core N3050 1.6GHz   4GB
#
#                    Memory                           Gpu       OpSys  Weight  \
# 0               128GB SSD  Intel Iris Plus Graphics 640       macOS  1.37kg
# 1     128GB Flash Storage        Intel HD Graphics 6000       macOS  1.34kg
# 2               256GB SSD         Intel HD Graphics 620       No OS  1.86kg
# 3               512GB SSD            AMD Radeon Pro 455       macOS  1.83kg
# 4               256GB SSD  Intel Iris Plus Graphics 650       macOS  1.37kg
# ...                   ...                           ...         ...     ...
# 1298            128GB SSD         Intel HD Graphics 520  Windows 10   1.8kg
# 1299            512GB SSD         Intel HD Graphics 520  Windows 10   1.3kg
# 1300   64GB Flash Storage             Intel HD Graphics  Windows 10   1.5kg
# 1301              1TB HDD            AMD Radeon R5 M330  Windows 10  2.19kg
# 1302            500GB HDD             Intel HD Graphics  Windows 10   2.2kg
#
#       Price_euros   Acer  ...   Vero  Xiaomi  2 in 1 Convertible  Gaming  \
# 0         1339.69  False  ...  False   False               False   False
# 1          898.94  False  ...  False   False               False   False
# 2          575.00  False  ...  False   False               False   False
# 3         2537.45  False  ...  False   False               False   False
# 4         1803.60  False  ...  False   False               False   False
# ...           ...    ...  ...    ...     ...                 ...     ...
# 1298       638.00  False  ...  False   False                True   False
# 1299      1499.00  False  ...  False   False                True   False
# 1300       229.00  False  ...  False   False               False   False
# 1301       764.00  False  ...  False   False               False   False
# 1302       369.00  False  ...  False   False               False   False
#
#       Netbook  Notebook  Ultrabook  Workstation  Screen width  Screen height
# 0       False     False       True        False          2560           1600
# 1       False     False       True        False          1440            900
# 2       False      True      False        False          1920           1080
# 3       False     False       True        False          2880           1800
# 4       False     False       True        False          2560           1600
# ...       ...       ...        ...          ...           ...            ...
# 1298    False     False      False        False          1920           1080
# 1299    False     False      False        False          3200           1800
# 1300    False      True      False        False          1366            768
# 1301    False      True      False        False          1366            768
# 1302    False      True      False        False          1366            768
#
# [1303 rows x 36 columns]

# %%
df['Cpu brand'] = df.Cpu.str.split(" ").apply(lambda x: x[0])
df['Cpu frequency'] = df.Cpu.str.split(" ").apply(lambda x: x[-1])
df = df.drop('Cpu', axis=1)
df
# Out:
#       laptop_ID  Inches   Ram               Memory  \
# 0             1    13.3   8GB            128GB SSD
# 1             2    13.3   8GB  128GB Flash Storage
# 2             3    15.6   8GB            256GB SSD
# 3             4    15.4  16GB            512GB SSD
# 4             5    13.3   8GB            256GB SSD
# ...         ...     ...   ...                  ...
# 1298       1316    14.0   4GB            128GB SSD
# 1299       1317    13.3  16GB            512GB SSD
# 1300       1318    14.0   2GB   64GB Flash Storage
# 1301       1319    15.6   6GB              1TB HDD
# 1302       1320    15.6   4GB            500GB HDD
#
#                                Gpu       OpSys  Weight  Price_euros   Acer  \
# 0     Intel Iris Plus Graphics 640       macOS  1.37kg      1339.69  False
# 1           Intel HD Graphics 6000       macOS  1.34kg       898.94  False
# 2            Intel HD Graphics 620       No OS  1.86kg       575.00  False
# 3               AMD Radeon Pro 455       macOS  1.83kg      2537.45  False
# 4     Intel Iris Plus Graphics 650       macOS  1.37kg      1803.60  False
# ...                            ...         ...     ...          ...    ...
# 1298         Intel HD Graphics 520  Windows 10   1.8kg       638.00  False
# 1299         Intel HD Graphics 520  Windows 10   1.3kg      1499.00  False
# 1300             Intel HD Graphics  Windows 10   1.5kg       229.00  False
# 1301            AMD Radeon R5 M330  Windows 10  2.19kg       764.00  False
# 1302             Intel HD Graphics  Windows 10   2.2kg       369.00  False
#
#       Apple  ...  2 in 1 Convertible  Gaming  Netbook  Notebook  Ultrabook  \
# 0      True  ...               False   False    False     False       True
# 1      True  ...               False   False    False     False       True
# 2     False  ...               False   False    False      True      False
# 3      True  ...               False   False    False     False       True
# 4      True  ...               False   False    False     False       True
# ...     ...  ...                 ...     ...      ...       ...        ...
# 1298  False  ...                True   False    False     False      False
# 1299  False  ...                True   False    False     False      False
# 1300  False  ...               False   False    False      True      False
# 1301  False  ...               False   False    False      True      False
# 1302  False  ...               False   False    False      True      False
#
#       Workstation  Screen width  Screen height  Cpu brand  Cpu frequency
# 0           False          2560           1600      Intel         2.3GHz
# 1           False          1440            900      Intel         1.8GHz
# 2           False          1920           1080      Intel         2.5GHz
# 3           False          2880           1800      Intel         2.7GHz
# 4           False          2560           1600      Intel         3.1GHz
# ...           ...           ...            ...        ...            ...
# 1298        False          1920           1080      Intel         2.5GHz
# 1299        False          3200           1800      Intel         2.5GHz
# 1300        False          1366            768      Intel         1.6GHz
# 1301        False          1366            768      Intel         2.5GHz
# 1302        False          1366            768      Intel         1.6GHz
#
# [1303 rows x 37 columns]

# %%
df['Cpu frequency'] = df['Cpu frequency'].str[:-3]
df
# Out:
#       laptop_ID  Inches   Ram               Memory  \
# 0             1    13.3   8GB            128GB SSD
# 1             2    13.3   8GB  128GB Flash Storage
# 2             3    15.6   8GB            256GB SSD
# 3             4    15.4  16GB            512GB SSD
# 4             5    13.3   8GB            256GB SSD
# ...         ...     ...   ...                  ...
# 1298       1316    14.0   4GB            128GB SSD
# 1299       1317    13.3  16GB            512GB SSD
# 1300       1318    14.0   2GB   64GB Flash Storage
# 1301       1319    15.6   6GB              1TB HDD
# 1302       1320    15.6   4GB            500GB HDD
#
#                                Gpu       OpSys  Weight  Price_euros   Acer  \
# 0     Intel Iris Plus Graphics 640       macOS  1.37kg      1339.69  False
# 1           Intel HD Graphics 6000       macOS  1.34kg       898.94  False
# 2            Intel HD Graphics 620       No OS  1.86kg       575.00  False
# 3               AMD Radeon Pro 455       macOS  1.83kg      2537.45  False
# 4     Intel Iris Plus Graphics 650       macOS  1.37kg      1803.60  False
# ...                            ...         ...     ...          ...    ...
# 1298         Intel HD Graphics 520  Windows 10   1.8kg       638.00  False
# 1299         Intel HD Graphics 520  Windows 10   1.3kg      1499.00  False
# 1300             Intel HD Graphics  Windows 10   1.5kg       229.00  False
# 1301            AMD Radeon R5 M330  Windows 10  2.19kg       764.00  False
# 1302             Intel HD Graphics  Windows 10   2.2kg       369.00  False
#
#       Apple  ...  2 in 1 Convertible  Gaming  Netbook  Notebook  Ultrabook  \
# 0      True  ...               False   False    False     False       True
# 1      True  ...               False   False    False     False       True
# 2     False  ...               False   False    False      True      False
# 3      True  ...               False   False    False     False       True
# 4      True  ...               False   False    False     False       True
# ...     ...  ...                 ...     ...      ...       ...        ...
# 1298  False  ...                True   False    False     False      False
# 1299  False  ...                True   False    False     False      False
# 1300  False  ...               False   False    False      True      False
# 1301  False  ...               False   False    False      True      False
# 1302  False  ...               False   False    False      True      False
#
#       Workstation  Screen width  Screen height  Cpu brand  Cpu frequency
# 0           False          2560           1600      Intel            2.3
# 1           False          1440            900      Intel            1.8
# 2           False          1920           1080      Intel            2.5
# 3           False          2880           1800      Intel            2.7
# 4           False          2560           1600      Intel            3.1
# ...           ...           ...            ...        ...            ...
# 1298        False          1920           1080      Intel            2.5
# 1299        False          3200           1800      Intel            2.5
# 1300        False          1366            768      Intel            1.6
# 1301        False          1366            768      Intel            2.5
# 1302        False          1366            768      Intel            1.6
#
# [1303 rows x 37 columns]

# %%
df['Ram'] = df['Ram'].str[:-2]
df
# Out:
#       laptop_ID  Inches Ram               Memory  \
# 0             1    13.3   8            128GB SSD
# 1             2    13.3   8  128GB Flash Storage
# 2             3    15.6   8            256GB SSD
# 3             4    15.4  16            512GB SSD
# 4             5    13.3   8            256GB SSD
# ...         ...     ...  ..                  ...
# 1298       1316    14.0   4            128GB SSD
# 1299       1317    13.3  16            512GB SSD
# 1300       1318    14.0   2   64GB Flash Storage
# 1301       1319    15.6   6              1TB HDD
# 1302       1320    15.6   4            500GB HDD
#
#                                Gpu       OpSys  Weight  Price_euros   Acer  \
# 0     Intel Iris Plus Graphics 640       macOS  1.37kg      1339.69  False
# 1           Intel HD Graphics 6000       macOS  1.34kg       898.94  False
# 2            Intel HD Graphics 620       No OS  1.86kg       575.00  False
# 3               AMD Radeon Pro 455       macOS  1.83kg      2537.45  False
# 4     Intel Iris Plus Graphics 650       macOS  1.37kg      1803.60  False
# ...                            ...         ...     ...          ...    ...
# 1298         Intel HD Graphics 520  Windows 10   1.8kg       638.00  False
# 1299         Intel HD Graphics 520  Windows 10   1.3kg      1499.00  False
# 1300             Intel HD Graphics  Windows 10   1.5kg       229.00  False
# 1301            AMD Radeon R5 M330  Windows 10  2.19kg       764.00  False
# 1302             Intel HD Graphics  Windows 10   2.2kg       369.00  False
#
#       Apple  ...  2 in 1 Convertible  Gaming  Netbook  Notebook  Ultrabook  \
# 0      True  ...               False   False    False     False       True
# 1      True  ...               False   False    False     False       True
# 2     False  ...               False   False    False      True      False
# 3      True  ...               False   False    False     False       True
# 4      True  ...               False   False    False     False       True
# ...     ...  ...                 ...     ...      ...       ...        ...
# 1298  False  ...                True   False    False     False      False
# 1299  False  ...                True   False    False     False      False
# 1300  False  ...               False   False    False      True      False
# 1301  False  ...               False   False    False      True      False
# 1302  False  ...               False   False    False      True      False
#
#       Workstation  Screen width  Screen height  Cpu brand  Cpu frequency
# 0           False          2560           1600      Intel            2.3
# 1           False          1440            900      Intel            1.8
# 2           False          1920           1080      Intel            2.5
# 3           False          2880           1800      Intel            2.7
# 4           False          2560           1600      Intel            3.1
# ...           ...           ...            ...        ...            ...
# 1298        False          1920           1080      Intel            2.5
# 1299        False          3200           1800      Intel            2.5
# 1300        False          1366            768      Intel            1.6
# 1301        False          1366            768      Intel            2.5
# 1302        False          1366            768      Intel            1.6
#
# [1303 rows x 37 columns]

# %%
df['Ram'] = df['Ram'].astype('int')
df['Cpu frequency'] = df['Cpu frequency'].astype('float')
df['Screen width'] = df['Screen width'].astype('int')
df['Screen height'] = df['Screen height'].astype('int')
df
# Out:
#       laptop_ID  Inches  Ram               Memory  \
# 0             1    13.3    8            128GB SSD
# 1             2    13.3    8  128GB Flash Storage
# 2             3    15.6    8            256GB SSD
# 3             4    15.4   16            512GB SSD
# 4             5    13.3    8            256GB SSD
# ...         ...     ...  ...                  ...
# 1298       1316    14.0    4            128GB SSD
# 1299       1317    13.3   16            512GB SSD
# 1300       1318    14.0    2   64GB Flash Storage
# 1301       1319    15.6    6              1TB HDD
# 1302       1320    15.6    4            500GB HDD
#
#                                Gpu       OpSys  Weight  Price_euros   Acer  \
# 0     Intel Iris Plus Graphics 640       macOS  1.37kg      1339.69  False
# 1           Intel HD Graphics 6000       macOS  1.34kg       898.94  False
# 2            Intel HD Graphics 620       No OS  1.86kg       575.00  False
# 3               AMD Radeon Pro 455       macOS  1.83kg      2537.45  False
# 4     Intel Iris Plus Graphics 650       macOS  1.37kg      1803.60  False
# ...                            ...         ...     ...          ...    ...
# 1298         Intel HD Graphics 520  Windows 10   1.8kg       638.00  False
# 1299         Intel HD Graphics 520  Windows 10   1.3kg      1499.00  False
# 1300             Intel HD Graphics  Windows 10   1.5kg       229.00  False
# 1301            AMD Radeon R5 M330  Windows 10  2.19kg       764.00  False
# 1302             Intel HD Graphics  Windows 10   2.2kg       369.00  False
#
#       Apple  ...  2 in 1 Convertible  Gaming  Netbook  Notebook  Ultrabook  \
# 0      True  ...               False   False    False     False       True
# 1      True  ...               False   False    False     False       True
# 2     False  ...               False   False    False      True      False
# 3      True  ...               False   False    False     False       True
# 4      True  ...               False   False    False     False       True
# ...     ...  ...                 ...     ...      ...       ...        ...
# 1298  False  ...                True   False    False     False      False
# 1299  False  ...                True   False    False     False      False
# 1300  False  ...               False   False    False      True      False
# 1301  False  ...               False   False    False      True      False
# 1302  False  ...               False   False    False      True      False
#
#       Workstation  Screen width  Screen height  Cpu brand  Cpu frequency
# 0           False          2560           1600      Intel            2.3
# 1           False          1440            900      Intel            1.8
# 2           False          1920           1080      Intel            2.5
# 3           False          2880           1800      Intel            2.7
# 4           False          2560           1600      Intel            3.1
# ...           ...           ...            ...        ...            ...
# 1298        False          1920           1080      Intel            2.5
# 1299        False          3200           1800      Intel            2.5
# 1300        False          1366            768      Intel            1.6
# 1301        False          1366            768      Intel            2.5
# 1302        False          1366            768      Intel            1.6
#
# [1303 rows x 37 columns]

# %%
df['Memory amount'] = df.Memory.str.split(" ").apply(lambda x: x[0])
df['Memory type'] = df.Memory.str.split(" ").apply(lambda x: x[1])
df['Memory type'].value_counts()
# Out:
# Memory type
# SSD       843
# HDD       375
# Flash      75
# Hybrid     10
# Name: count, dtype: int64

# %%
df['Memory amount'].value_counts()
# Out:
# Memory amount
# 256GB    508
# 1TB      240
# 128GB    177
# 512GB    140
# 500GB    132
# 32GB      45
# 64GB      17
# 2TB       16
# 1.0TB     10
# 16GB      10
# 180GB      5
# 240GB      1
# 8GB        1
# 508GB      1
# Name: count, dtype: int64

# %%
def turn_memory_amount_into_MB(value):
    if "GB" in value:
        return float(value[:value.find("GB")])*1000
    if "TB" in value:
        return float(value[:value.find("TB")])*1000000
df['Memory amount'] = df['Memory amount'].apply(turn_memory_amount_into_MB)

# %%
df['Memory amount']
# Out:
# 0        128000.0
# 1        128000.0
# 2        256000.0
# 3        512000.0
# 4        256000.0
#           ...
# 1298     128000.0
# 1299     512000.0
# 1300      64000.0
# 1301    1000000.0
# 1302     500000.0
# Name: Memory amount, Length: 1303, dtype: float64

# %%
df = df.drop('Memory', axis=1)
df
# Out:
#       laptop_ID  Inches  Ram                           Gpu       OpSys  \
# 0             1    13.3    8  Intel Iris Plus Graphics 640       macOS
# 1             2    13.3    8        Intel HD Graphics 6000       macOS
# 2             3    15.6    8         Intel HD Graphics 620       No OS
# 3             4    15.4   16            AMD Radeon Pro 455       macOS
# 4             5    13.3    8  Intel Iris Plus Graphics 650       macOS
# ...         ...     ...  ...                           ...         ...
# 1298       1316    14.0    4         Intel HD Graphics 520  Windows 10
# 1299       1317    13.3   16         Intel HD Graphics 520  Windows 10
# 1300       1318    14.0    2             Intel HD Graphics  Windows 10
# 1301       1319    15.6    6            AMD Radeon R5 M330  Windows 10
# 1302       1320    15.6    4             Intel HD Graphics  Windows 10
#
#       Weight  Price_euros   Acer  Apple   Asus  ...  Netbook  Notebook  \
# 0     1.37kg      1339.69  False   True  False  ...    False     False
# 1     1.34kg       898.94  False   True  False  ...    False     False
# 2     1.86kg       575.00  False  False  False  ...    False      True
# 3     1.83kg      2537.45  False   True  False  ...    False     False
# 4     1.37kg      1803.60  False   True  False  ...    False     False
# ...      ...          ...    ...    ...    ...  ...      ...       ...
# 1298   1.8kg       638.00  False  False  False  ...    False     False
# 1299   1.3kg      1499.00  False  False  False  ...    False     False
# 1300   1.5kg       229.00  False  False  False  ...    False      True
# 1301  2.19kg       764.00  False  False  False  ...    False      True
# 1302   2.2kg       369.00  False  False   True  ...    False      True
#
#       Ultrabook  Workstation  Screen width  Screen height  Cpu brand  \
# 0          True        False          2560           1600      Intel
# 1          True        False          1440            900      Intel
# 2         False        False          1920           1080      Intel
# 3          True        False          2880           1800      Intel
# 4          True        False          2560           1600      Intel
# ...         ...          ...           ...            ...        ...
# 1298      False        False          1920           1080      Intel
# 1299      False        False          3200           1800      Intel
# 1300      False        False          1366            768      Intel
# 1301      False        False          1366            768      Intel
# 1302      False        False          1366            768      Intel
#
#       Cpu frequency  Memory amount  Memory type
# 0               2.3       128000.0          SSD
# 1               1.8       128000.0        Flash
# 2               2.5       256000.0          SSD
# 3               2.7       512000.0          SSD
# 4               3.1       256000.0          SSD
# ...             ...            ...          ...
# 1298            2.5       128000.0          SSD
# 1299            2.5       512000.0          SSD
# 1300            1.6        64000.0        Flash
# 1301            2.5      1000000.0          HDD
# 1302            1.6       500000.0          HDD
#
# [1303 rows x 38 columns]

# %%
df['Weight'] = df['Weight'].str[:-2]
df
# Out:
#       laptop_ID  Inches  Ram                           Gpu       OpSys Weight  \
# 0             1    13.3    8  Intel Iris Plus Graphics 640       macOS   1.37
# 1             2    13.3    8        Intel HD Graphics 6000       macOS   1.34
# 2             3    15.6    8         Intel HD Graphics 620       No OS   1.86
# 3             4    15.4   16            AMD Radeon Pro 455       macOS   1.83
# 4             5    13.3    8  Intel Iris Plus Graphics 650       macOS   1.37
# ...         ...     ...  ...                           ...         ...    ...
# 1298       1316    14.0    4         Intel HD Graphics 520  Windows 10    1.8
# 1299       1317    13.3   16         Intel HD Graphics 520  Windows 10    1.3
# 1300       1318    14.0    2             Intel HD Graphics  Windows 10    1.5
# 1301       1319    15.6    6            AMD Radeon R5 M330  Windows 10   2.19
# 1302       1320    15.6    4             Intel HD Graphics  Windows 10    2.2
#
#       Price_euros   Acer  Apple   Asus  ...  Netbook  Notebook  Ultrabook  \
# 0         1339.69  False   True  False  ...    False     False       True
# 1          898.94  False   True  False  ...    False     False       True
# 2          575.00  False  False  False  ...    False      True      False
# 3         2537.45  False   True  False  ...    False     False       True
# 4         1803.60  False   True  False  ...    False     False       True
# ...           ...    ...    ...    ...  ...      ...       ...        ...
# 1298       638.00  False  False  False  ...    False     False      False
# 1299      1499.00  False  False  False  ...    False     False      False
# 1300       229.00  False  False  False  ...    False      True      False
# 1301       764.00  False  False  False  ...    False      True      False
# 1302       369.00  False  False   True  ...    False      True      False
#
#       Workstation  Screen width  Screen height  Cpu brand  Cpu frequency  \
# 0           False          2560           1600      Intel            2.3
# 1           False          1440            900      Intel            1.8
# 2           False          1920           1080      Intel            2.5
# 3           False          2880           1800      Intel            2.7
# 4           False          2560           1600      Intel            3.1
# ...           ...           ...            ...        ...            ...
# 1298        False          1920           1080      Intel            2.5
# 1299        False          3200           1800      Intel            2.5
# 1300        False          1366            768      Intel            1.6
# 1301        False          1366            768      Intel            2.5
# 1302        False          1366            768      Intel            1.6
#
#       Memory amount  Memory type
# 0          128000.0          SSD
# 1          128000.0        Flash
# 2          256000.0          SSD
# 3          512000.0          SSD
# 4          256000.0          SSD
# ...             ...          ...
# 1298       128000.0          SSD
# 1299       512000.0          SSD
# 1300        64000.0        Flash
# 1301      1000000.0          HDD
# 1302       500000.0          HDD
#
# [1303 rows x 38 columns]

# %%
df['Weight'] = df['Weight'].astype('float')
df
# Out:
#       laptop_ID  Inches  Ram                           Gpu       OpSys  \
# 0             1    13.3    8  Intel Iris Plus Graphics 640       macOS
# 1             2    13.3    8        Intel HD Graphics 6000       macOS
# 2             3    15.6    8         Intel HD Graphics 620       No OS
# 3             4    15.4   16            AMD Radeon Pro 455       macOS
# 4             5    13.3    8  Intel Iris Plus Graphics 650       macOS
# ...         ...     ...  ...                           ...         ...
# 1298       1316    14.0    4         Intel HD Graphics 520  Windows 10
# 1299       1317    13.3   16         Intel HD Graphics 520  Windows 10
# 1300       1318    14.0    2             Intel HD Graphics  Windows 10
# 1301       1319    15.6    6            AMD Radeon R5 M330  Windows 10
# 1302       1320    15.6    4             Intel HD Graphics  Windows 10
#
#       Weight  Price_euros   Acer  Apple   Asus  ...  Netbook  Notebook  \
# 0       1.37      1339.69  False   True  False  ...    False     False
# 1       1.34       898.94  False   True  False  ...    False     False
# 2       1.86       575.00  False  False  False  ...    False      True
# 3       1.83      2537.45  False   True  False  ...    False     False
# 4       1.37      1803.60  False   True  False  ...    False     False
# ...      ...          ...    ...    ...    ...  ...      ...       ...
# 1298    1.80       638.00  False  False  False  ...    False     False
# 1299    1.30      1499.00  False  False  False  ...    False     False
# 1300    1.50       229.00  False  False  False  ...    False      True
# 1301    2.19       764.00  False  False  False  ...    False      True
# 1302    2.20       369.00  False  False   True  ...    False      True
#
#       Ultrabook  Workstation  Screen width  Screen height  Cpu brand  \
# 0          True        False          2560           1600      Intel
# 1          True        False          1440            900      Intel
# 2         False        False          1920           1080      Intel
# 3          True        False          2880           1800      Intel
# 4          True        False          2560           1600      Intel
# ...         ...          ...           ...            ...        ...
# 1298      False        False          1920           1080      Intel
# 1299      False        False          3200           1800      Intel
# 1300      False        False          1366            768      Intel
# 1301      False        False          1366            768      Intel
# 1302      False        False          1366            768      Intel
#
#       Cpu frequency  Memory amount  Memory type
# 0               2.3       128000.0          SSD
# 1               1.8       128000.0        Flash
# 2               2.5       256000.0          SSD
# 3               2.7       512000.0          SSD
# 4               3.1       256000.0          SSD
# ...             ...            ...          ...
# 1298            2.5       128000.0          SSD
# 1299            2.5       512000.0          SSD
# 1300            1.6        64000.0        Flash
# 1301            2.5      1000000.0          HDD
# 1302            1.6       500000.0          HDD
#
# [1303 rows x 38 columns]

# %%
df['Gpu brand'] = df.Gpu.str.split(" ").apply(lambda x: x[0])
df = df.drop('Gpu', axis=1)
df
# Out:
#       laptop_ID  Inches  Ram       OpSys  Weight  Price_euros   Acer  Apple  \
# 0             1    13.3    8       macOS    1.37      1339.69  False   True
# 1             2    13.3    8       macOS    1.34       898.94  False   True
# 2             3    15.6    8       No OS    1.86       575.00  False  False
# 3             4    15.4   16       macOS    1.83      2537.45  False   True
# 4             5    13.3    8       macOS    1.37      1803.60  False   True
# ...         ...     ...  ...         ...     ...          ...    ...    ...
# 1298       1316    14.0    4  Windows 10    1.80       638.00  False  False
# 1299       1317    13.3   16  Windows 10    1.30      1499.00  False  False
# 1300       1318    14.0    2  Windows 10    1.50       229.00  False  False
# 1301       1319    15.6    6  Windows 10    2.19       764.00  False  False
# 1302       1320    15.6    4  Windows 10    2.20       369.00  False  False
#
#        Asus  Chuwi  ...  Notebook  Ultrabook  Workstation  Screen width  \
# 0     False  False  ...     False       True        False          2560
# 1     False  False  ...     False       True        False          1440
# 2     False  False  ...      True      False        False          1920
# 3     False  False  ...     False       True        False          2880
# 4     False  False  ...     False       True        False          2560
# ...     ...    ...  ...       ...        ...          ...           ...
# 1298  False  False  ...     False      False        False          1920
# 1299  False  False  ...     False      False        False          3200
# 1300  False  False  ...      True      False        False          1366
# 1301  False  False  ...      True      False        False          1366
# 1302   True  False  ...      True      False        False          1366
#
#       Screen height  Cpu brand  Cpu frequency  Memory amount  Memory type  \
# 0              1600      Intel            2.3       128000.0          SSD
# 1               900      Intel            1.8       128000.0        Flash
# 2              1080      Intel            2.5       256000.0          SSD
# 3              1800      Intel            2.7       512000.0          SSD
# 4              1600      Intel            3.1       256000.0          SSD
# ...             ...        ...            ...            ...          ...
# 1298           1080      Intel            2.5       128000.0          SSD
# 1299           1800      Intel            2.5       512000.0          SSD
# 1300            768      Intel            1.6        64000.0        Flash
# 1301            768      Intel            2.5      1000000.0          HDD
# 1302            768      Intel            1.6       500000.0          HDD
#
#       Gpu brand
# 0         Intel
# 1         Intel
# 2         Intel
# 3           AMD
# 4         Intel
# ...         ...
# 1298      Intel
# 1299      Intel
# 1300      Intel
# 1301        AMD
# 1302      Intel
#
# [1303 rows x 38 columns]

# %%
df = df.join(pd.get_dummies(df.OpSys))
df = df.drop('OpSys', axis=1)
df
# Out:
#       laptop_ID  Inches  Ram  Weight  Price_euros   Acer  Apple   Asus  Chuwi  \
# 0             1    13.3    8    1.37      1339.69  False   True  False  False
# 1             2    13.3    8    1.34       898.94  False   True  False  False
# 2             3    15.6    8    1.86       575.00  False  False  False  False
# 3             4    15.4   16    1.83      2537.45  False   True  False  False
# 4             5    13.3    8    1.37      1803.60  False   True  False  False
# ...         ...     ...  ...     ...          ...    ...    ...    ...    ...
# 1298       1316    14.0    4    1.80       638.00  False  False  False  False
# 1299       1317    13.3   16    1.30      1499.00  False  False  False  False
# 1300       1318    14.0    2    1.50       229.00  False  False  False  False
# 1301       1319    15.6    6    2.19       764.00  False  False  False  False
# 1302       1320    15.6    4    2.20       369.00  False  False   True  False
#
#        Dell  ...  Gpu brand  Android  Chrome OS  Linux  Mac OS X  No OS  \
# 0     False  ...      Intel    False      False  False     False  False
# 1     False  ...      Intel    False      False  False     False  False
# 2     False  ...      Intel    False      False  False     False   True
# 3     False  ...        AMD    False      False  False     False  False
# 4     False  ...      Intel    False      False  False     False  False
# ...     ...  ...        ...      ...        ...    ...       ...    ...
# 1298  False  ...      Intel    False      False  False     False  False
# 1299  False  ...      Intel    False      False  False     False  False
# 1300  False  ...      Intel    False      False  False     False  False
# 1301  False  ...        AMD    False      False  False     False  False
# 1302  False  ...      Intel    False      False  False     False  False
#
#       Windows 10  Windows 10 S  Windows 7  macOS
# 0          False         False      False   True
# 1          False         False      False   True
# 2          False         False      False  False
# 3          False         False      False   True
# 4          False         False      False   True
# ...          ...           ...        ...    ...
# 1298        True         False      False  False
# 1299        True         False      False  False
# 1300        True         False      False  False
# 1301        True         False      False  False
# 1302        True         False      False  False
#
# [1303 rows x 46 columns]

# %%
cpu_categories = pd.get_dummies(df['Cpu brand'])
cpu_categories.columns = [col + "_CPU" for col in cpu_categories.columns]

df = df.join(cpu_categories)
df = df.drop("Cpu brand", axis=1)
df
# Out:
#       laptop_ID  Inches  Ram  Weight  Price_euros   Acer  Apple   Asus  Chuwi  \
# 0             1    13.3    8    1.37      1339.69  False   True  False  False
# 1             2    13.3    8    1.34       898.94  False   True  False  False
# 2             3    15.6    8    1.86       575.00  False  False  False  False
# 3             4    15.4   16    1.83      2537.45  False   True  False  False
# 4             5    13.3    8    1.37      1803.60  False   True  False  False
# ...         ...     ...  ...     ...          ...    ...    ...    ...    ...
# 1298       1316    14.0    4    1.80       638.00  False  False  False  False
# 1299       1317    13.3   16    1.30      1499.00  False  False  False  False
# 1300       1318    14.0    2    1.50       229.00  False  False  False  False
# 1301       1319    15.6    6    2.19       764.00  False  False  False  False
# 1302       1320    15.6    4    2.20       369.00  False  False   True  False
#
#        Dell  ...  Linux  Mac OS X  No OS  Windows 10  Windows 10 S  Windows 7  \
# 0     False  ...  False     False  False       False         False      False
# 1     False  ...  False     False  False       False         False      False
# 2     False  ...  False     False   True       False         False      False
# 3     False  ...  False     False  False       False         False      False
# 4     False  ...  False     False  False       False         False      False
# ...     ...  ...    ...       ...    ...         ...           ...        ...
# 1298  False  ...  False     False  False        True         False      False
# 1299  False  ...  False     False  False        True         False      False
# 1300  False  ...  False     False  False        True         False      False
# 1301  False  ...  False     False  False        True         False      False
# 1302  False  ...  False     False  False        True         False      False
#
#       macOS  AMD_CPU  Intel_CPU  Samsung_CPU
# 0      True    False       True        False
# 1      True    False       True        False
# 2     False    False       True        False
# 3      True    False       True        False
# 4      True    False       True        False
# ...     ...      ...        ...          ...
# 1298  False    False       True        False
# 1299  False    False       True        False
# 1300  False    False       True        False
# 1301  False    False       True        False
# 1302  False    False       True        False
#
# [1303 rows x 48 columns]

# %%
gpu_categories = pd.get_dummies(df['Gpu brand'])
gpu_categories.columns = [col + "_GPU" for col in gpu_categories.columns]

df = df.join(gpu_categories)
df = df.drop("Gpu brand", axis=1)
df
# Out:
#       laptop_ID  Inches  Ram  Weight  Price_euros   Acer  Apple   Asus  Chuwi  \
# 0             1    13.3    8    1.37      1339.69  False   True  False  False
# 1             2    13.3    8    1.34       898.94  False   True  False  False
# 2             3    15.6    8    1.86       575.00  False  False  False  False
# 3             4    15.4   16    1.83      2537.45  False   True  False  False
# 4             5    13.3    8    1.37      1803.60  False   True  False  False
# ...         ...     ...  ...     ...          ...    ...    ...    ...    ...
# 1298       1316    14.0    4    1.80       638.00  False  False  False  False
# 1299       1317    13.3   16    1.30      1499.00  False  False  False  False
# 1300       1318    14.0    2    1.50       229.00  False  False  False  False
# 1301       1319    15.6    6    2.19       764.00  False  False  False  False
# 1302       1320    15.6    4    2.20       369.00  False  False   True  False
#
#        Dell  ...  Windows 10 S  Windows 7  macOS  AMD_CPU  Intel_CPU  \
# 0     False  ...         False      False   True    False       True
# 1     False  ...         False      False   True    False       True
# 2     False  ...         False      False  False    False       True
# 3     False  ...         False      False   True    False       True
# 4     False  ...         False      False   True    False       True
# ...     ...  ...           ...        ...    ...      ...        ...
# 1298  False  ...         False      False  False    False       True
# 1299  False  ...         False      False  False    False       True
# 1300  False  ...         False      False  False    False       True
# 1301  False  ...         False      False  False    False       True
# 1302  False  ...         False      False  False    False       True
#
#       Samsung_CPU  AMD_GPU  ARM_GPU  Intel_GPU  Nvidia_GPU
# 0           False    False    False       True       False
# 1           False    False    False       True       False
# 2           False    False    False       True       False
# 3           False     True    False      False       False
# 4           False    False    False       True       False
# ...           ...      ...      ...        ...         ...
# 1298        False    False    False       True       False
# 1299        False    False    False       True       False
# 1300        False    False    False       True       False
# 1301        False     True    False      False       False
# 1302        False    False    False       True       False
#
# [1303 rows x 51 columns]

# %%
df.columns
# Out:
# Index(['laptop_ID', 'Inches', 'Ram', 'Weight', 'Price_euros', 'Acer', 'Apple',
#        'Asus', 'Chuwi', 'Dell', 'Fujitsu', 'Google', 'HP', 'Huawei', 'LG',
#        'Lenovo', 'MSI', 'Mediacom', 'Microsoft', 'Razer', 'Samsung', 'Toshiba',
#        'Vero', 'Xiaomi', '2 in 1 Convertible', 'Gaming', 'Netbook', 'Notebook',
#        'Ultrabook', 'Workstation', 'Screen width', 'Screen height',
#        'Cpu frequency', 'Memory amount', 'Memory type', 'Android', 'Chrome OS',
#        'Linux', 'Mac OS X', 'No OS', 'Windows 10', 'Windows 10 S', 'Windows 7',
#        'macOS', 'AMD_CPU', 'Intel_CPU', 'Samsung_CPU', 'AMD_GPU', 'ARM_GPU',
#        'Intel_GPU', 'Nvidia_GPU'],
#       dtype='object')

# %%
df = df.join(pd.get_dummies(df['Memory type']))
df = df.drop('Memory type', axis=1)
df
# Out:
#       laptop_ID  Inches  Ram  Weight  Price_euros   Acer  Apple   Asus  Chuwi  \
# 0             1    13.3    8    1.37      1339.69  False   True  False  False
# 1             2    13.3    8    1.34       898.94  False   True  False  False
# 2             3    15.6    8    1.86       575.00  False  False  False  False
# 3             4    15.4   16    1.83      2537.45  False   True  False  False
# 4             5    13.3    8    1.37      1803.60  False   True  False  False
# ...         ...     ...  ...     ...          ...    ...    ...    ...    ...
# 1298       1316    14.0    4    1.80       638.00  False  False  False  False
# 1299       1317    13.3   16    1.30      1499.00  False  False  False  False
# 1300       1318    14.0    2    1.50       229.00  False  False  False  False
# 1301       1319    15.6    6    2.19       764.00  False  False  False  False
# 1302       1320    15.6    4    2.20       369.00  False  False   True  False
#
#        Dell  ...  Intel_CPU  Samsung_CPU  AMD_GPU  ARM_GPU  Intel_GPU  \
# 0     False  ...       True        False    False    False       True
# 1     False  ...       True        False    False    False       True
# 2     False  ...       True        False    False    False       True
# 3     False  ...       True        False     True    False      False
# 4     False  ...       True        False    False    False       True
# ...     ...  ...        ...          ...      ...      ...        ...
# 1298  False  ...       True        False    False    False       True
# 1299  False  ...       True        False    False    False       True
# 1300  False  ...       True        False    False    False       True
# 1301  False  ...       True        False     True    False      False
# 1302  False  ...       True        False    False    False       True
#
#       Nvidia_GPU  Flash    HDD  Hybrid    SSD
# 0          False  False  False   False   True
# 1          False   True  False   False  False
# 2          False  False  False   False   True
# 3          False  False  False   False   True
# 4          False  False  False   False   True
# ...          ...    ...    ...     ...    ...
# 1298       False  False  False   False   True
# 1299       False  False  False   False   True
# 1300       False   True  False   False  False
# 1301       False  False   True   False  False
# 1302       False  False   True   False  False
#
# [1303 rows x 54 columns]

# %%
df.corr()
# Out:
#                     laptop_ID    Inches       Ram    Weight  Price_euros  \
# laptop_ID            1.000000 -0.087796 -0.028607 -0.011798     0.067830
# Inches              -0.087796  1.000000  0.237993  0.827631     0.068197
# Ram                 -0.028607  0.237993  1.000000  0.383874     0.743007
# Weight              -0.011798  0.827631  0.383874  1.000000     0.210370
# Price_euros          0.067830  0.068197  0.743007  0.210370     1.000000
# Acer                -0.057721  0.009435 -0.138432  0.056444    -0.208349
# Apple               -0.119585 -0.158850  0.023950 -0.138191     0.080688
# Asus                -0.044252  0.112766  0.088634  0.101332    -0.010376
# Chuwi               -0.043348 -0.017426 -0.035117 -0.022536    -0.055646
# Dell                -0.013628  0.045288  0.082241  0.088465     0.048509
# Fujitsu              0.009268  0.019637 -0.016214  0.014053    -0.027135
# Google              -0.012039 -0.091551  0.021591 -0.067790     0.038086
# HP                   0.059002 -0.026828 -0.149220 -0.098842    -0.041291
# Huawei              -0.047711 -0.055473 -0.002948 -0.058276     0.016851
# LG                   0.022884  0.001667  0.021591 -0.071401     0.067053
# Lenovo               0.031822 -0.055055 -0.036538 -0.029767    -0.029007
# MSI                  0.054900  0.207877  0.190425  0.194364     0.180100
# Mediacom            -0.015268 -0.080415 -0.067495 -0.077511    -0.087161
# Microsoft           -0.051140 -0.072377 -0.005114 -0.080508     0.047562
# Razer                0.029371 -0.025923  0.159724  0.017343     0.233756
# Samsung              0.029782 -0.069898  0.037484 -0.090664     0.034584
# Toshiba              0.031935 -0.090946  0.010946 -0.117163     0.040339
# Vero                 0.019820 -0.046401 -0.053302 -0.059121    -0.071972
# Xiaomi              -0.030861 -0.022075  0.017663 -0.034930     0.000776
# 2 in 1 Convertible   0.066227 -0.314691  0.017560 -0.236693     0.072675
# Gaming               0.032384  0.402666  0.481728  0.591756     0.375789
# Netbook              0.058880 -0.314030 -0.102976 -0.154059    -0.097572
# Notebook            -0.049769  0.246907 -0.416486  0.034893    -0.549248
# Ultrabook           -0.040689 -0.417950  0.087470 -0.439952     0.255658
# Workstation          0.001167  0.098893  0.062353  0.097031     0.249752
# Chrome OS            -0.096815  0.426685 -0.092469 -0.012793 -0.118009
# Linux                -0.047154 -0.055238  0.192357 -0.019657 -0.151714
# Mac OS X             -0.052311  0.318038 -0.049963 -0.006912 -0.106401
# No OS                 0.051134 -0.057085  0.177839 -0.020314 -0.136941
# Windows 10            0.095472 -0.170004 -0.108831 -0.028258  0.191108
# Windows 10 S         -0.052311  0.022759 -0.049963 -0.006912  0.037502
# Windows 7            -0.043869 -0.046741 -0.055245  0.127851  0.051767
# macOS                -0.066813  0.041501 -0.063814 -0.008828  0.041839
# AMD_CPU              -0.148763 -0.039760  0.104765  0.104276 -0.098910
# Intel_CPU             0.150019  0.024982 -0.101698 -0.103172  0.103005
# Samsung_CPU          -0.018445  0.112141 -0.017617 -0.002437 -0.037517
# AMD_GPU              -0.266460 -0.089392  0.143436  0.117714 -0.113810
# ARM_GPU              -0.018445  0.112141 -0.017617 -0.002437 -0.037517
# Intel_GPU            -0.741936  0.201805 -0.016335 -0.062650 -0.071435
# Nvidia_GPU            1.000000 -0.157338 -0.088642 -0.020398  0.164375
# Flash                -0.157338  1.000000 -0.157099 -0.021734 -0.334554
# HDD                  -0.088642 -0.157099  1.000000 -0.055904 -0.860551
# Hybrid               -0.020398 -0.021734 -0.055904  1.000000 -0.119052
# SSD                   0.164375 -0.334554 -0.860551 -0.119052  1.000000
#
# [54 rows x 54 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(18,15))
sns.heatmap(df.corr(), annot=True, cmap="YlGnBu")
# Out:
# <Axes: >

# %%
target_correlations = df.corr()['Price_euros'].apply(abs).sort_values()
target_correlations
# Out:
# Xiaomi                0.000776
# Asus                  0.010376
# Mac OS X              0.015656
# Huawei                0.016851
# Windows 10 S          0.018312
# ARM_GPU               0.018431
# Samsung_CPU           0.018431
# Fujitsu               0.027135
# Lenovo                0.029007
# Samsung               0.034584
# Google                0.038086
# Android               0.038700
# Hybrid                0.039386
# Toshiba               0.040339
# HP                    0.041291
# Microsoft             0.047562
# Dell                  0.048509
# Chuwi                 0.055646
# LG                    0.067053
# laptop_ID             0.067830
# Inches                0.068197
# Vero                  0.071972
# 2 in 1 Convertible    0.072675
# Apple                 0.080688
# Mediacom              0.087161
# macOS                 0.089928
# Netbook               0.097572
# Chrome OS             0.118684
# Memory amount         0.122365
# Windows 10            0.137048
# Windows 7             0.152381
# Linux                 0.162060
# No OS                 0.177094
# MSI                   0.180100
# AMD_CPU               0.180111
# Intel_CPU             0.181127
# Intel_GPU             0.184205
# AMD_GPU               0.199415
# Acer                  0.208349
# Weight                0.210370
# Flash                 0.210823
# Razer                 0.233756
# Workstation           0.249752
# Ultrabook             0.255658
# Nvidia_GPU            0.348797
# Gaming                0.375789
# HDD                   0.426121
# Cpu frequency         0.430293
# SSD                   0.513609
# Notebook              0.549248
# Screen height         0.552809
# Screen width          0.556529
# Ram                   0.743007
# Price_euros           1.000000
# Name: Price_euros, dtype: float64

# %%
selected_features = target_correlations[-21:].index
selected_features = list(selected_features)
selected_features
# Out:
# ['MSI',
#  'AMD_CPU',
#  'Intel_CPU',
#  'Intel_GPU',
#  'AMD_GPU',
#  'Acer',
#  'Weight',
#  'Flash',
#  'Razer',
#  'Workstation',
#  'Ultrabook',
#  'Nvidia_GPU',
#  'Gaming',
#  'HDD',
#  'Cpu frequency',
#  'SSD',
#  'Notebook',
#  'Screen height',
#  'Screen width',
#  'Ram',
#  'Price_euros']

# %%
limited_df = df[selected_features]
limited_df
# Out:
#         MSI  AMD_CPU  Intel_CPU  Intel_GPU  AMD_GPU   Acer  Weight  Flash  \
# 0     False    False       True       True    False  False    1.37  False
# 1     False    False       True       True    False  False    1.34   True
# 2     False    False       True       True    False  False    1.86  False
# 3     False    False       True      False     True  False    1.83  False
# 4     False    False       True       True    False  False    1.37  False
# ...     ...      ...        ...        ...      ...    ...     ...    ...
# 1298  False    False       True       True    False  False    1.80  False
# 1299  False    False       True       True    False  False    1.30  False
# 1300  False    False       True       True    False  False    1.50   True
# 1301  False    False       True      False     True  False    2.19  False
# 1302  False    False       True       True    False  False    2.20  False
#
#       Razer  Workstation  ...  Nvidia_GPU  Gaming    HDD  Cpu frequency  \
# 0     False        False  ...       False   False  False            2.3
# 1     False        False  ...       False   False  False            1.8
# 2     False        False  ...       False   False  False            2.5
# 3     False        False  ...       False   False  False            2.7
# 4     False        False  ...       False   False  False            3.1
# ...     ...          ...  ...         ...     ...    ...            ...
# 1298  False        False  ...       False   False  False            2.5
# 1299  False        False  ...       False   False  False            2.5
# 1300  False        False  ...       False   False  False            1.6
# 1301  False        False  ...       False   False   True            2.5
# 1302  False        False  ...       False   False   True            1.6
#
#         SSD  Notebook  Screen height  Screen width  Ram  Price_euros
# 0      True     False           1600          2560    8      1339.69
# 1     False     False            900          1440    8       898.94
# 2      True      True           1080          1920    8       575.00
# 3      True     False           1800          2880   16      2537.45
# 4      True     False           1600          2560    8      1803.60
# ...     ...       ...            ...           ...  ...          ...
# 1298   True     False           1080          1920    4       638.00
# 1299   True     False           1800          3200   16      1499.00
# 1300  False      True            768          1366    2       229.00
# 1301  False      True            768          1366    6       764.00
# 1302  False      True            768          1366    4       369.00
#
# [1303 rows x 21 columns]

# %%
plt.figure(figsize=(15,10))
sns.heatmap(limited_df.corr(), annot=True, cmap="YlGnBu")
# Out:
# <Axes: >

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor  

x, y = limited_df.drop('Price_euros', axis=1), limited_df['Price_euros']
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.15)
scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.transform(x_test)

# %%
forest = RandomForestRegressor()
forest.fit(x_train_scaled, y_train)
# Out:
# RandomForestRegressor()

# %%
forest.score(x_test_scaled, y_test)
# Out:
# 0.8509161241761753

# %%
y_pred = forest.predict(x_test_scaled)

# %%
plt.figure(figsize=(12, 8))
plt.scatter(y_pred, y_test)
plt.plot(range(0, 6000), range(0, 6000), c='red')

# %%
x_test.iloc[0]
# Out:
# MSI              False
# AMD_CPU          False
# Intel_CPU         True
# Intel_GPU        False
# AMD_GPU          False
# Acer             False
# Weight            2.16
# Flash            False
# Razer            False
# Workstation      False
# Ultrabook        False
# Nvidia_GPU        True
# Gaming           False
# HDD              False
# Cpu frequency      1.8
# SSD               True
# Notebook          True
# Screen height     1080
# Screen width      1920
# Ram                  8
# Name: 117, dtype: object

# %%
x_new_scaled = scaler.transform([x_test.iloc[0]])
forest.predict(x_new_scaled)
# Out:
# C:\Users\FUJITSU\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([1103.5051])

# %%
y_test.iloc[0]
# Out:
# 1130.33
